# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('customer_churn_data.csv')

# %%
df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df.shape
# Out:
# (2000, 16)

# %%
df.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df.describe()
# Out:
#          year    customer_id         age  no_of_days_subscribed  \
# count  2000.0    2000.000000  2000.00000            2000.000000
# mean   2015.0  554887.157500    38.69050              99.750000
# std       0.0  261033.690318    10.20641              39.755386
# min    2015.0  100198.000000    18.00000               1.000000
# 25%    2015.0  328634.750000    32.00000              73.000000
# 50%    2015.0  567957.500000    37.00000              99.000000
# 75%    2015.0  773280.250000    44.00000             127.000000
# max    2015.0  999961.000000    82.00000             243.000000
#
#        weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# count          2000.000000         2000.000000         2000.000000
# mean            270.178425           10.198700           30.620780
# std              80.551627            2.785519            9.129165
# min               0.000000            0.000000            0.000000
# ...

# %%
df.describe(include=object)
# Out:
#         phone_no gender multi_screen mail_subscribed
# count       2000   1976         2000            2000
# unique      2000      2            2               2
# top     409-8743   Male           no              no
# freq           1   1053         1802            1430

# %%
df.isnull().sum()
# Out:
# year                       0
# customer_id                0
# phone_no                   0
# gender                    24
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %%
sns.displot(df['age'])

# %%
sns.kdeplot(df['weekly_mins_watched'])
# Out:
# <Axes: xlabel='weekly_mins_watched', ylabel='Density'>

# %%
sns.kdeplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.boxplot(y=df['no_of_days_subscribed'])
# Out:
# <Axes: ylabel='no_of_days_subscribed'>

# %%
sns.boxplot(y=df['no_of_days_subscribed'], whis=1)
# Out:
# <Axes: ylabel='no_of_days_subscribed'>

# %%
sns.boxplot(y=df['videos_watched'])
# Out:
# <Axes: ylabel='videos_watched'>

# %%
df['gender'].unique()
# Out:
# array(['Female', nan, 'Male'], dtype=object)

# %%
df['gender'].value_counts()
# Out:
# Male      1053
# Female     923
# Name: gender, dtype: int64

# %%
plt.pie(df['gender'].value_counts(), labels=df['gender'].value_counts().index,autopct='%.2f%%')
plt.show()

# %% [markdown]
# For gender column, we should fill the value with:
# mode - most frequent value - male
# least frequent value - female
# respective ratios
#
# Here I am using Mode(max count) to fill inplace of missing values

# %%
df['gender'].fillna(df['gender'].mode()[0],inplace=True) 
df['gender']
# Out:
# 0       Female
# 1       Female
# 2       Female
# 3       Female
# 4       Female
#          ...
# 1995    Female
# 1996      Male
# 1997      Male
# 1998      Male
# 1999      Male
# Name: gender, Length: 2000, dtype: object

# %%
df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080    Male   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df.isnull().sum()
# Out:
# year                       0
# customer_id                0
# phone_no                   0
# gender                     0
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %% [markdown]
# -I have replaced missing in gender column now remaining is two columns

# %%
 df['maximum_days_inactive'].median()
# Out:
# 3.0

# %%
df['maximum_days_inactive'].mean()
# Out:
# 3.2505070993914806

# %% [markdown]
# here I can replace with either mean or median according to your assumption or thinking as median gives me perfect whole number i go for median

# %%
df.fillna({'maximum_days_inactive': df['maximum_days_inactive'].median()}, inplace=True)

# %%
df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080    Male   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df.isnull().sum()
# Out:
# year                       0
# customer_id                0
# phone_no                   0
# gender                     0
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive      0
# customer_support_calls     0
# churn                     35
# dtype: int64

# %% [markdown]
# here I have replaced Maximum_days_inactive column  with median of that column so remaining one column has missing value

# %%
df['churn'].value_counts(dropna=False)
# Out:
# 0.0    1703
# 1.0     262
# NaN      35
# Name: churn, dtype: int64

# %% [markdown]
# 1.0->leave
# 0.0->stay
#
# this column says where the customer(user) contiues(stay) or discontinues(leave) from this OTT platform
#
# Here i am replacing the missing values by frequency(most repeated occurance) using mode() according to
# my analysis  based on CUSTOMER CALL column and some other column

# %%
df['churn'].fillna(df['churn'].mode()[0],inplace=True) 
df['churn']
# Out:
# 0       0.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 1995    0.0
# 1996    0.0
# 1997    0.0
# 1998    0.0
# 1999    1.0
# Name: churn, Length: 2000, dtype: float64

# %%
df.isnull().sum()
# Out:
# year                      0
# customer_id               0
# phone_no                  0
# gender                    0
# age                       0
# no_of_days_subscribed     0
# multi_screen              0
# mail_subscribed           0
# weekly_mins_watched       0
# minimum_daily_mins        0
# maximum_daily_mins        0
# weekly_max_night_mins     0
# videos_watched            0
# maximum_days_inactive     0
# customer_support_calls    0
# churn                     0
# dtype: int64

# %% [markdown]
# Now i have cleaned and handled missing values by replcaing it with mode and median |

# %%
df['churn'].value_counts()
# Out:
# 0.0    1738
# 1.0     262
# Name: churn, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  2000 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   2000 non-null   float64
# ...

# %% [markdown]
# ###

# %%
sns.countplot(x='churn', data=df)
# Out:
# <Axes: xlabel='churn', ylabel='count'>

# %% [markdown]
# Now i am going to delete the column which are not usefull for analysis.Here year,phone_no,mail_subscribed column is some unwanted data for analysing whether User will stay or not

# %%
df.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743  Female   36                     62
# 1  2015       100643  340-5930  Female   39                    149
# 2  2015       100756  372-3750  Female   65                    126
# 3  2015       101595  331-4902  Female   24                    131
# 4  2015       101653  351-8398  Female   40                    191
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82               1
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
cols_to_delete = ['year', 'phone_no', 'mail_subscribed']
df1 = df.drop(cols_to_delete, axis=1)
df1.head()
# Out:
#    customer_id  gender  age  no_of_days_subscribed multi_screen  \
# 0       100198  Female   36                     62           no
# 1       100643  Female   39                    149           no
# 2       100756  Female   65                    126           no
# 3       101595  Female   24                    131           no
# 4       101653  Female   40                    191           no
#
#    weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# 0               148.35                12.2               16.81
# 1               294.45                 7.7               33.37
# 2                87.30                11.9                9.89
# 3               321.30                 9.5               36.41
# 4               243.00                10.9               27.54
#
#    weekly_max_night_mins  videos_watched  maximum_days_inactive  \
# 0                     82               1                    4.0
# 1                     87               3                    3.0
# ...

# %% [markdown]
# i am removing those columns and taking remaining dataset in another variable to analyse for better understanding

# %%
df1.isna().sum()
# Out:
# customer_id               0
# gender                    0
# age                       0
# no_of_days_subscribed     0
# multi_screen              0
# weekly_mins_watched       0
# minimum_daily_mins        0
# maximum_daily_mins        0
# weekly_max_night_mins     0
# videos_watched            0
# maximum_days_inactive     0
# customer_support_calls    0
# churn                     0
# dtype: int64

# %%
df1['multi_screen']
# Out:
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
#         ..
# 1995    no
# 1996    no
# 1997    no
# 1998    no
# 1999    no
# Name: multi_screen, Length: 2000, dtype: object

# %%
df1['multi_screen'].value_counts()
df1
# Out:
#       customer_id  gender  age  no_of_days_subscribed multi_screen  \
# 0          100198  Female   36                     62           no
# 1          100643  Female   39                    149           no
# 2          100756  Female   65                    126           no
# 3          101595  Female   24                    131           no
# 4          101653  Female   40                    191           no
# ...           ...     ...  ...                    ...          ...
# 1995       997132  Female   54                     75           no
# 1996       998086    Male   45                    127           no
# 1997       998474    Male   53                     94           no
# 1998       998934    Male   40                     94           no
# 1999       999961    Male   37                     73           no
#
#       weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# 0                  148.35                12.2               16.81
# ...

# %%
gender_dummies = pd.get_dummies(df1['gender'])
gender_dummies
# Out:
#       Female  Male
# 0          1     0
# 1          1     0
# 2          1     0
# 3          1     0
# 4          1     0
# ...      ...   ...
# 1995       1     0
# 1996       0     1
# 1997       0     1
# 1998       0     1
# 1999       0     1
#
# [2000 rows x 2 columns]

# %%
df1=pd.concat([df1, gender_dummies], axis=1)
df1
# Out:
#       customer_id  gender  age  no_of_days_subscribed multi_screen  \
# 0          100198  Female   36                     62           no
# 1          100643  Female   39                    149           no
# 2          100756  Female   65                    126           no
# 3          101595  Female   24                    131           no
# 4          101653  Female   40                    191           no
# ...           ...     ...  ...                    ...          ...
# 1995       997132  Female   54                     75           no
# 1996       998086    Male   45                    127           no
# 1997       998474    Male   53                     94           no
# 1998       998934    Male   40                     94           no
# 1999       999961    Male   37                     73           no
#
#       weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# 0                  148.35                12.2               16.81
# ...

# %%
#df1=df1.drop(['gender'], axis=1, inplace=True)
#df1
df2 = df1.drop(['gender'], axis=1,inplace=True)
df2

# %%
df2=df1.set_index('customer_id')
df2
# Out:
#              age  no_of_days_subscribed multi_screen  weekly_mins_watched  \
# customer_id
# 100198        36                     62           no               148.35
# 100643        39                    149           no               294.45
# 100756        65                    126           no                87.30
# 101595        24                    131           no               321.30
# 101653        40                    191           no               243.00
# ...          ...                    ...          ...                  ...
# 997132        54                     75           no               182.25
# 998086        45                    127           no               273.45
# 998474        53                     94           no               128.85
# 998934        40                     94           no               178.05
# 999961        37                     73           no               326.70
#
# ...

# %%
df1.corr()
# Out:
# C:\Users\32013\AppData\Local\Temp\ipykernel_18952\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                         customer_id       age  no_of_days_subscribed  \
# customer_id                1.000000  0.023830              -0.011457
# age                        0.023830  1.000000               0.038822
# no_of_days_subscribed     -0.011457  0.038822               1.000000
# weekly_mins_watched       -0.013830  0.016316               0.000657
# minimum_daily_mins         0.033733 -0.000676               0.016329
# maximum_daily_mins        -0.013834  0.016328               0.000652
# weekly_max_night_mins      0.009713  0.016645              -0.001967
# videos_watched             0.063967  0.013076               0.019414
# ...

# %%
df3 = df2[['age', 'no_of_days_subscribed', 'Male','Female', 'customer_support_calls', 'videos_watched']]

# %%
df3
# Out:
#              age  no_of_days_subscribed  Male  Female  customer_support_calls  \
# customer_id
# 100198        36                     62     0       1                       1
# 100643        39                    149     0       1                       2
# 100756        65                    126     0       1                       5
# 101595        24                    131     0       1                       3
# 101653        40                    191     0       1                       1
# ...          ...                    ...   ...     ...                     ...
# 997132        54                     75     0       1                       2
# 998086        45                    127     1       0                       1
# 998474        53                     94     1       0                       0
# 998934        40                     94     1       0                       3
# 999961        37                     73     1       0                       1
#
# ...

# %% [markdown]
# I have taken few columns above which is more usefull for analysing whether user stay or not also other columns also used like 'maximum_days_inactive' column etc,  but these has more impact

# %%
df3.corr()
# Out:
#                              age  no_of_days_subscribed      Male    Female  \
# age                     1.000000               0.038822 -0.008814  0.008814
# no_of_days_subscribed   0.038822               1.000000 -0.001785  0.001785
# Male                   -0.008814              -0.001785  1.000000 -1.000000
# Female                  0.008814               0.001785 -1.000000  1.000000
# customer_support_calls  0.000618               0.013419  0.007537 -0.007537
# videos_watched          0.013076               0.019414  0.027563 -0.027563
#
#                         customer_support_calls  videos_watched
# age                                   0.000618        0.013076
# no_of_days_subscribed                 0.013419        0.019414
# Male                                  0.007537        0.027563
# Female                               -0.007537       -0.027563
# customer_support_calls                1.000000       -0.001201
# ...

# %% [markdown]
# converting  gender column(categorical column) to numerical column for better understanding in CORR above as gender is not displayed for object

# %%
sns.heatmap(df3.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df2.corr())
# Out:
# C:\Users\32013\AppData\Local\Temp\ipykernel_18952\325437066.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr())
# <Axes: >

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df2.corr(), annot=True, cmap='coolwarm')
# Out:
# C:\Users\32013\AppData\Local\Temp\ipykernel_18952\1056399111.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(), annot=True, cmap='coolwarm')
# <Axes: >

# %%
sns.heatmap(df3.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
